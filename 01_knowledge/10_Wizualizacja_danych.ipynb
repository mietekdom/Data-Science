# %% [markdown]
# <a href="https://colab.research.google.com/github/mietekdom/Data-Science/blob/master/01_knowledge/10_Wizualizacja_danych.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# Wykres liniowy

# %%
_ = plt.plot([1, 2], [3, 4])

# %%
plt.plot([1, 2], [3, 4], label='line', color='green') 
plt.xlabel('oś X') # podpis osi X
plt.ylabel('oś Y') # podpis osi Y
plt.title('Wykres') #tytuł wykresu
_ = plt.legend() # legenda

# %%
plt.plot([1, 2, 4], [3, 4, 2], label='line', color='green') 
plt.xlabel('oś X') # podpis osi X
plt.ylabel('oś Y') # podpis osi Y
plt.title('Wykres') #tytuł wykresu
_ = plt.legend() # legenda

# %%
x = np.arange(-3, 3, 0.1)
x_sin = np.sin(x)
x_cos = np.cos(x)

plt.plot(x, x_sin)
_ = plt.plot(x, x_cos)

# %% [markdown]
# Tworzenie wielu wykresów

# %%
fig = plt.figure(figsize=(10, 8)) # wielkość wykresu


plt.subplot(131) # pusty obiekt 1 - liczba wierszy, 3 - liczba kolumn, 1 - konkretny wykres
plt.plot([0, 1, 2], [3, 2, 5])
plt.subplot(132)
plt.plot([1, 2, 3], [5, 1, 5], 'r--')
plt.subplot(133)
plt.plot([1, 2, 3], [5, 1, 5], 'ro')

# %% [markdown]
# Wykres słupkowy

# %%
plt.bar(x=[0, 1, 2, 3], height=[1.2, 3.4, 2.2, 4.2])
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar(x=['a', 'b', 'c', 'd'], height=[1.2, 3.4, 2.2, 4.2])
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(y=['a', 'b', 'c', 'd'], width=[1.2, 3.4, 2.2, 4.2]) # wykres horyzontalny
# Out:
# <BarContainer object of 4 artists>

# %%
Wykres punktowy

# %%
x1 = np.random.randn(300)
x2 = np.random.randn(300)
plt.scatter(x=x1, y=x2)

# %%
x1 = np.random.randn(300)
x2 = np.random.randn(300)
x3 = np.random.randn(300) * 50
plt.scatter(x=x1, y=x2, s=x3) # s - wielkość punktów na wykresie
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/collections.py:885: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
x1 = np.random.randn(300)
x2 = np.random.randn(300)
x3 = np.random.randn(300) * 50
plt.scatter(x=x1, y=x2, s=x3, alpha=0.5) # aplha - przejrzystość
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/collections.py:885: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
