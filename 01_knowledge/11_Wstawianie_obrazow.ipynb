# %% [markdown]
# <a href="https://colab.research.google.com/github/mietekdom/Data-Science/blob/master/01_knowledge/11_Wstawianie_obrazow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img = mpimg.imread('20200722_140016.jpg') # zaczytywanie zdjęcia jako obiekt array
img
# Out:
# array([[[255, 253, 254],
#         [255, 253, 254],
#         [255, 253, 254],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[252, 250, 251],
#         [253, 251, 252],
#         [254, 252, 253],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[253, 251, 252],
#         [254, 252, 253],
#         [254, 252, 253],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[ 60,  51,  36],
#         [ 58,  49,  34],
#         [ 58,  49,  34],
#         ...,
#         [ 68,  70,  67],
#         [ 76,  77,  72],
#         [ 83,  82,  78]],
#
#        [[ 62,  52,  40],
#         [ 61,  51,  39],
#         [ 62,  53,  38],
#         ...,
#         [ 65,  67,  64],
#         [ 70,  69,  65],
#         [ 76,  75,  71]],
#
#        [[ 60,  50,  38],
#         [ 58,  48,  36],
#         [ 60,  50,  38],
# ...

# %%
img.shape # rozmiar obrazu
# Out:
# (3096, 4128, 3)

# %%
plt.imshow(img) # wyświetlanie zdjęcia

# %%
plt.imshow(img) # wyświetlanie zdjęcia
_ = plt.axis('off') # bez osi

# %%
fig = plt.figure(figsize=(12, 10))
plt.subplot(221) #dodajemy siatke 2 na 2
plt.imshow(mpimg.imread('20200724_143417.jpg'))
plt.subplot(222) #dodajemy siatke 2 na 2
plt.imshow(mpimg.imread('20200724_141454.jpg'))
plt.subplot(223) #dodajemy siatke 2 na 2
plt.imshow(mpimg.imread('20200722_143622.jpg'))
plt.subplot(224) #dodajemy siatke 2 na 2
plt.imshow(mpimg.imread('20200722_140016.jpg'))

# %%
fig = plt.figure(figsize=(12, 10)) # to samo co wyzej tylko w automatyzacji
for idx, img in enumerate(['20200724_143417.jpg', '20200724_141454.jpg', '20200722_143622.jpg', '20200722_140016.jpg']):
  plt.subplot(220 + idx + 1)
  plt.imshow(mpimg.imread(img))

# %%
fig = plt.figure(figsize=(12, 10)) # to samo co wyzej tylko w automatyzacji
for idx, img in enumerate(['20200724_143417.jpg', '20200724_141454.jpg', '20200722_143622.jpg', '20200722_140016.jpg']):
  plt.subplot(140 + idx + 1)
  plt.imshow(mpimg.imread(img))
