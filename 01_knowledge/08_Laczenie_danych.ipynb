# %% [markdown]
# <a href="https://colab.research.google.com/github/mietekdom/Data-Science/blob/master/01_knowledge/08_%C5%82aczenie_danych.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
print(f'Pandas: {pd.__version__}')
print(f'Numpy: {np.__version__}')
# Out:
# Pandas: 1.0.5
# Numpy: 1.18.5

# %%
def fetch_financial_data(company='AMZN'):
    """Pobiera dane dotyczące notowań spółek na giełdzie według symboli
    na serwisie stooq.pl"""
    import pandas_datareader.data as web
    return web.DataReader(name=company, data_source='stooq')

apple = fetch_financial_data('AAPL')
amazon = fetch_financial_data('AMZN')
google = fetch_financial_data('GOOGL')
uber = fetch_financial_data('UBER')
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas_datareader/compat/__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
apple.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1257 entries, 2020-08-31 to 2015-09-03
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    1257 non-null   float64
#  1   High    1257 non-null   float64
#  2   Low     1257 non-null   float64
#  3   Close   1257 non-null   float64
#  4   Volume  1257 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 58.9 KB

# %%
amazon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1257 entries, 2020-08-31 to 2015-09-03
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    1257 non-null   float64
#  1   High    1257 non-null   float64
#  2   Low     1257 non-null   float64
#  3   Close   1257 non-null   float64
#  4   Volume  1257 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 58.9 KB

# %%
apple.head()
# Out:
#               Open    High     Low   Close     Volume
# Date
# 2020-08-31  127.58  131.00  126.00  129.04  225702688
# 2020-08-28  126.01  126.44  124.58  124.81  187629916
# 2020-08-27  127.14  127.48  123.83  125.01  155552384
# 2020-08-26  126.18  126.99  125.08  126.52  163022268
# 2020-08-25  124.70  125.18  123.05  124.82  211495788

# %% [markdown]
# Zmiana nazwy kolumn dla kazdej tabeli

# %%
apple.columns = ['apple_' + col.lower() for col in apple.columns]
amazon.columns = ['amazon_' + col.lower() for col in amazon.columns]
google.columns = ['google_' + col.lower() for col in google.columns]
uber.columns = ['uber_' + col.lower() for col in uber.columns]

# %%
apple.head()
# Out:
#             apple_open  apple_high  apple_low  apple_close  apple_volume
# Date
# 2020-08-31      127.58      131.00     126.00       129.04     225702688
# 2020-08-28      126.01      126.44     124.58       124.81     187629916
# 2020-08-27      127.14      127.48     123.83       125.01     155552384
# 2020-08-26      126.18      126.99     125.08       126.52     163022268
# 2020-08-25      124.70      125.18     123.05       124.82     211495788

# %% [markdown]
# Łaczenie kolumn

# %%
df_all = pd.concat(objs=[apple, amazon, google, uber], axis=1)
df_all
# Out:
#             apple_open  apple_high  ...  uber_close  uber_volume
# Date                                ...
# 2015-09-03      25.990      26.055  ...         NaN          NaN
# 2015-09-04      25.180      25.518  ...         NaN          NaN
# 2015-09-08      25.792      26.008  ...         NaN          NaN
# 2015-09-09      26.285      26.345  ...         NaN          NaN
# 2015-09-10      25.480      26.168  ...         NaN          NaN
# ...                ...         ...  ...         ...          ...
# 2020-08-25     124.700     125.180  ...       31.19   10056762.0
# 2020-08-26     126.180     126.990  ...       32.30   20599776.0
# 2020-08-27     127.140     127.480  ...       32.80   21306491.0
# 2020-08-28     126.010     126.440  ...       33.80   17833021.0
# 2020-08-31     127.580     131.000  ...       33.63   14980621.0
#
# [1257 rows x 20 columns]

# %%
df_all.describe().T # informacje o zbiorze
# Out:
#                 count          mean  ...           75%           max
# apple_open     1257.0  4.439184e+01  ...  5.158800e+01  1.287000e+02
# apple_high     1257.0  4.485622e+01  ...  5.211800e+01  1.310000e+02
# apple_low      1257.0  4.397956e+01  ...  5.113000e+01  1.260000e+02
# apple_close    1257.0  4.444940e+01  ...  5.171800e+01  1.290400e+02
# apple_volume   1257.0  1.401993e+08  ...  1.657493e+08  5.650922e+08
# amazon_open    1257.0  1.384144e+03  ...  1.818080e+03  3.450050e+03
# amazon_high    1257.0  1.398411e+03  ...  1.830150e+03  3.495000e+03
# amazon_low     1257.0  1.368438e+03  ...  1.800790e+03  3.405000e+03
# amazon_close   1257.0  1.384360e+03  ...  1.817270e+03  3.450960e+03
# amazon_volume  1257.0  4.264948e+06  ...  5.103803e+06  1.655260e+07
# google_open    1257.0  1.037351e+03  ...  1.193690e+03  1.646610e+03
# google_high    1257.0  1.046977e+03  ...  1.201990e+03  1.652790e+03
# google_low     1257.0  1.027534e+03  ...  1.182030e+03  1.625605e+03
# ...

# %%
pd.set_option('display.float_format', lambda x: f'{x: .2f}') # edycja zbioru - dwie lidzby po przecinku
df_all.describe().T # informacje o zbiorze
# Out:
#                  count          mean  ...           75%           max
# apple_open     1257.00         44.39  ...         51.59        128.70
# apple_high     1257.00         44.86  ...         52.12        131.00
# apple_low      1257.00         43.98  ...         51.13        126.00
# apple_close    1257.00         44.45  ...         51.72        129.04
# apple_volume   1257.00  140199340.15  ...  165749328.00  565092196.00
# amazon_open    1257.00       1384.14  ...       1818.08       3450.05
# amazon_high    1257.00       1398.41  ...       1830.15       3495.00
# amazon_low     1257.00       1368.44  ...       1800.79       3405.00
# amazon_close   1257.00       1384.36  ...       1817.27       3450.96
# amazon_volume  1257.00    4264947.73  ...    5103803.00   16552598.00
# google_open    1257.00       1037.35  ...       1193.69       1646.61
# google_high    1257.00       1046.98  ...       1201.99       1652.79
# ...

# %%
# współczynnik korelacji dla poszczególnych zmiennych
df_all.corr()
# Out:
#                apple_open  apple_high  ...  uber_close  uber_volume
# apple_open           1.00        1.00  ...       -0.31         0.12
# apple_high           1.00        1.00  ...       -0.32         0.13
# apple_low            1.00        1.00  ...       -0.31         0.11
# apple_close          1.00        1.00  ...       -0.31         0.12
# apple_volume        -0.01       -0.00  ...       -0.37         0.38
# amazon_open          0.93        0.93  ...       -0.10        -0.02
# amazon_high          0.93        0.93  ...       -0.12        -0.01
# amazon_low           0.93        0.93  ...       -0.10        -0.03
# amazon_close         0.93        0.93  ...       -0.11        -0.02
# amazon_volume        0.12        0.12  ...       -0.26         0.29
# google_open          0.93        0.93  ...       -0.19         0.10
# google_high          0.93        0.93  ...       -0.21         0.11
# google_low           0.93        0.92  ...       -0.17         0.07
# ...

# %%
# wszystkie kolumny - listowanie
df_all.columns
# Out:
# Index(['apple_open', 'apple_high', 'apple_low', 'apple_close', 'apple_volume',
#        'amazon_open', 'amazon_high', 'amazon_low', 'amazon_close',
#        'amazon_volume', 'google_open', 'google_high', 'google_low',
#        'google_close', 'google_volume', 'uber_open', 'uber_high', 'uber_low',
#        'uber_close', 'uber_volume'],
#       dtype='object')

# %%
closes = [col for col in df_all.columns if col.endswith('close')] # listowanie kolumn 'close'
closes
# Out:
# ['apple_close', 'amazon_close', 'google_close', 'uber_close']

# %%
df_all[closes]
# Out:
#             apple_close  amazon_close  google_close  uber_close
# Date
# 2015-09-03        25.50        504.72        637.05         nan
# 2015-09-04        25.24        499.00        628.96         nan
# 2015-09-08        25.95        517.54        643.88         nan
# 2015-09-09        25.45        516.89        643.41         nan
# 2015-09-10        26.01        522.24        651.08         nan
# ...                 ...           ...           ...         ...
# 2020-08-25       124.82       3346.49       1605.85       31.19
# 2020-08-26       126.52       3441.85       1644.13       32.30
# 2020-08-27       125.01       3400.00       1628.52       32.80
# 2020-08-28       124.81       3401.80       1639.43       33.80
# 2020-08-31       129.04       3450.96       1629.53       33.63
#
# [1257 rows x 4 columns]

# %%
df_all[closes].corr() # koleralcja zmiennych 'close'
# Out:
#               apple_close  amazon_close  google_close  uber_close
# apple_close          1.00          0.93          0.93       -0.31
# amazon_close         0.93          1.00          0.94       -0.11
# google_close         0.93          0.94          1.00       -0.19
# uber_close          -0.31         -0.11         -0.19        1.00

# %%
closes = [col for col in df_all.columns if col.endswith('close') or col.endswith('volume')]
closes
# Out:
# ['apple_close',
#  'apple_volume',
#  'amazon_close',
#  'amazon_volume',
#  'google_close',
#  'google_volume',
#  'uber_close',
#  'uber_volume']

# %%
df_all[closes].corr()
# Out:
#                apple_close  apple_volume  ...  uber_close  uber_volume
# apple_close           1.00         -0.01  ...       -0.31         0.12
# apple_volume         -0.01          1.00  ...       -0.37         0.38
# amazon_close          0.93         -0.06  ...       -0.11        -0.02
# amazon_volume         0.11          0.43  ...       -0.26         0.29
# google_close          0.93         -0.13  ...       -0.19         0.09
# google_volume         0.05          0.43  ...       -0.26         0.35
# uber_close           -0.31         -0.37  ...        1.00        -0.31
# uber_volume           0.12          0.38  ...       -0.31         1.00
#
# [8 rows x 8 columns]

# %% [markdown]
# Łączenie danych append

# %%
uber.head()
# Out:
#             uber_open  uber_high  uber_low  uber_close  uber_volume
# Date
# 2020-08-31      33.62      33.92     33.14       33.63     14980621
# 2020-08-28      33.00      33.94     32.82       33.80     17833021
# 2020-08-27      32.40      33.07     32.27       32.80     21306491
# 2020-08-26      31.01      32.71     30.95       32.30     20599776
# 2020-08-25      31.04      31.19     30.60       31.19     10056762

# %%
uber_6 = uber[uber.index.month == 6] # wycinamy dane dla miesiąca czerwca
uber_6
# Out:
#             uber_open  uber_high  uber_low  uber_close  uber_volume
# Date
# 2020-06-30      30.83      31.25     30.13       31.08     21282810
# 2020-06-29      29.51      29.75     28.39       29.63     20795402
# 2020-06-26      30.44      30.44     29.21       29.61     46482331
# 2020-06-25      30.00      30.86     29.56       30.58     19142789
# 2020-06-24      32.75      32.93     30.45       30.46     29477229
# 2020-06-23      32.88      33.21     32.59       33.05     13622126
# 2020-06-22      32.43      32.85     31.43       32.68     17790276
# 2020-06-19      33.98      34.02     32.27       32.30     29426285
# 2020-06-18      33.00      33.44     32.80       33.40     15495838
# 2020-06-17      33.50      33.59     33.01       33.29     14827742
# 2020-06-16      34.00      34.17     32.43       33.49     21377119
# 2020-06-15      31.16      32.68     31.02       32.67     21350290
# 2020-06-12      32.73      32.74     31.04       32.24     27685169
# ...

# %%
uber_7 = uber[uber.index.month == 7] # wycinamy dane dla miesiąca lipca
uber_7
# Out:
#             uber_open  uber_high  uber_low  uber_close  uber_volume
# Date
# 2020-07-31      30.40      30.42     29.79       30.26     16360999
# 2020-07-30      30.65      30.68     29.97       30.24     13062912
# 2020-07-29      30.92      31.26     30.77       31.02      8215892
# 2020-07-28      30.79      31.24     30.35       30.81     12977145
# 2020-07-27      31.21      31.60     30.75       30.99     10182302
# 2020-07-24      31.74      31.80     30.47       31.18     16896059
# 2020-07-23      32.33      33.02     31.98       32.17     12749770
# 2020-07-22      32.44      32.88     32.33       32.66     12128382
# 2020-07-21      34.16      34.23     32.53       32.55     16743293
# 2020-07-20      32.48      33.92     32.35       33.66     16213609
# 2020-07-17      32.58      32.82     31.85       32.55     13667896
# 2020-07-16      32.05      32.59     31.55       32.35     11090750
# 2020-07-15      32.10      32.97     31.68       32.81     20976523
# ...

# %%
# łaczenie danych z czerwca i lipca

# %%
uber_6_7 = uber_6.append(uber_7)
uber_6_7
# Out:
#             uber_open  uber_high  uber_low  uber_close  uber_volume
# Date
# 2020-06-30      30.83      31.25     30.13       31.08     21282810
# 2020-06-29      29.51      29.75     28.39       29.63     20795402
# 2020-06-26      30.44      30.44     29.21       29.61     46482331
# 2020-06-25      30.00      30.86     29.56       30.58     19142789
# 2020-06-24      32.75      32.93     30.45       30.46     29477229
# ...               ...        ...       ...         ...          ...
# 2019-07-08      43.59      43.85     42.75       42.95      9304101
# 2019-07-05      44.31      44.55     43.01       43.53      8239452
# 2019-07-03      44.00      44.46     43.79       44.23      3380003
# 2019-07-02      44.55      44.68     43.75       44.00     11881274
# 2019-07-01      46.98      47.04     44.06       44.27     17739998
#
# [86 rows x 5 columns]
